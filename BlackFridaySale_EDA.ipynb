# %%
import pandas as pd
import numpy as np
import seaborn as sb

# %%
df=pd.read_csv('BlackFriday.csv')
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df.shape
# Out:
# (537577, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %%
df.dropna()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 1       1000001  P00248942      F   0-17          10             A
# 6       1000004  P00184942      M  46-50           7             B
# 13      1000005  P00145042      M  26-35          20             A
# 14      1000006  P00231342      F  51-55           9             A
# 16      1000006   P0096642      F  51-55           9             A
# ...         ...        ...    ...    ...         ...           ...
# 537549  1004734  P00345842      M  51-55           1             B
# 537551  1004735  P00313442      M  46-50           3             C
# 537562  1004736  P00146742      M  18-25          20             A
# 537571  1004737  P00221442      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 1                               2               0                   1
# ...

# %%
del df['Product_Category_2']
del df['Product_Category_3']

# %%
print('-'*60)
print('Updated Shape of Dataset :',df.shape)
print('-'*60)
print('Updated Dataset :')
df.isnull().sum()
# Out:
# ------------------------------------------------------------
# Updated Shape of Dataset : (537577, 10)
# ------------------------------------------------------------
# Updated Dataset :
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Purchase                      0
# dtype: int64

# %% [markdown]
# # Analyzing Columns

# %% [markdown]
# ### Column : User_ID

# %%
df['User_ID'].nunique()
# Out:
# 5891

# %%
df['User_ID'].unique()
# Out:
# array([1000001, 1000002, 1000003, ..., 1004113, 1005391, 1001529],
#       dtype=int64)

# %% [markdown]
# ### Column : Product_ID

# %%
df['Product_ID'].nunique()
# Out:
# 3623

# %%
df['Product_ID'].unique()
# Out:
# array(['P00069042', 'P00248942', 'P00087842', ..., 'P00038842',
#        'P00295642', 'P00091742'], dtype=object)

# %% [markdown]
# ### Column : Gender

# %%
df['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %% [markdown]
# ### Column : Age

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %% [markdown]
# ### Column : Occupation

# %%
df['Occupation'].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6], dtype=int64)

# %% [markdown]
# ### Column : City_Category

# %%
df['City_Category'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %% [markdown]
# ### Column : Stay_In_Current_City_Years

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %% [markdown]
# ### Column : Marital_Status

# %%
df['Marital_Status'].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# ### Column : Product_Category_1

# %%
df['Product_Category_1'].unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9], dtype=int64)

# %% [markdown]
# ### Column : Purchase

# %%
# Total Amount spent
df['Purchase'].sum()
# Out:
# 5017668378

# %%
# avg spent on 1 product
df['Purchase'].sum()/len(df['Purchase'])
# Out:
# 9333.859852635065

# %%
# Automating
for i in df.columns:
    print(i, ':',df[i].nunique())
# Out:
# User_ID : 5891
# Product_ID : 3623
# Gender : 2
# Age : 7
# Occupation : 21
# City_Category : 3
# Stay_In_Current_City_Years : 5
# Marital_Status : 2
# Product_Category_1 : 18
# Purchase : 17959

# %% [markdown]
# # Analyzing Gender Column

# %% [markdown]
# ### Approach 1

# %%
countM=0
for i in df['Gender']:
    if i=='M':
        countM+=1
countF=0
for i in df['Gender']:
    if i=='F':
        countF+=1
print('No. of Males : ',countM)
print('No. of Females : ',countF)
# Out:
# No. of Males :  405380
# No. of Females :  132197

# %%
data=pd.DataFrame({ 'Ratio' : [countM,countF]}, index=['Male','Female'])

# %%
data
# Out:
#          Ratio
# Male    405380
# Female  132197

# %%
data.plot(kind='pie', y='Ratio', autopct='%.2f', figsize=(5,5))
# Out:
# <Axes: ylabel='Ratio'>

# %% [markdown]
# ### Approach 2

# %%
df.groupby('Gender').size()
# Out:
# Gender
# F    132197
# M    405380
# dtype: int64

# %% [markdown]
# ## Pie Chart-Gender

# %%
df.groupby('Gender').size().plot(kind = 'pie', 
                                 autopct='%.2f', 
                                 title='Gender Ratio',
                                 figsize=(5,5))
# Out:
# <Axes: title={'center': 'Gender Ratio'}>

# %% [markdown]
# ## Bar Graph-Gender

# %%
df.groupby('Gender').size().plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %% [markdown]
# ### % of men & women individually spending on purchase

# %%
#df.groupby('Gender').sum()['Purchase'].plot(kind = 'pie', autopct = "%0.1f")
#Not working

# %% [markdown]
# # Age Column

# %%
df.head(5)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
df.groupby('Age').size()
# Out:
# Age
# 0-17      14707
# 18-25     97634
# 26-35    214690
# 36-45    107499
# 46-50     44526
# 51-55     37618
# 55+       20903
# dtype: int64

# %%
df.groupby('Age').size().plot(kind='bar', figsize=(8,4), title='Purcahse Distribution by Age')
# Out:
# <Axes: title={'center': 'Purcahse Distribution by Age'}, xlabel='Age'>

# %%
len(df[df['Age']=='0-17'])
# Out:
# 14707

# %%
lst=[]

for i in df['Age'].unique():
    lst.append([i,df[df['Age']==i]['Product_ID'].nunique()])
lst
# Out:
# [['0-17', 2300],
#  ['55+', 2573],
#  ['26-35', 3419],
#  ['46-50', 3099],
#  ['51-55', 2877],
#  ['36-45', 3318],
#  ['18-25', 3213]]

# %%
data=pd.DataFrame(lst, columns=['Age','Products'])
data
# Out:
#      Age  Products
# 0   0-17      2300
# 1    55+      2573
# 2  26-35      3419
# 3  46-50      3099
# 4  51-55      2877
# 5  36-45      3318
# 6  18-25      3213

# %%
data.plot(kind='bar', x='Age', y='Products')
# Out:
# <Axes: xlabel='Age'>

# %%
df.groupby('Age').sum()['Purchase'].plot(kind='bar', title='Amount spent by age')
# Out:
# <Axes: title={'center': 'Amount spent by age'}, xlabel='Age'>

# %%
# Average spendings per age group
df.groupby('Age')['Purchase'].mean().plot(kind='pie', title='Avg spending per age grp', autopct="%.2f")
# Out:
# <Axes: title={'center': 'Avg spending per age grp'}, ylabel='Purchase'>

# %% [markdown]
# # Marital_status column

# %%
df.groupby('Marital_Status').size().plot(kind='pie', title='% of who are married-1 and single-0', autopct="%.2f")
# Out:
# <Axes: title={'center': '% of who are married-1 and single-0'}>

# %% [markdown]
# # Multicolumn Analysis

# %% [markdown]
# ### Based on Age , count of men & women

# %%
sb.countplot(x='Age', hue='Gender', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sb.set(rc={'figure.figsize': (8,4)})
sb.countplot(x='Age', hue='Gender', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %% [markdown]
# ### Based on Gender , count of age groups

# %%
sb.countplot(x='Gender', hue='Age', data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %% [markdown]
# ### Based on Gender , maital staus of M & F

# %%
sb.countplot(x='Gender', hue='Marital_Status', data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %% [markdown]
# ### Based on Marital status, count of Gender

# %%
sb.set(rc={'figure.figsize':(6,6)})
sb.countplot(x='Marital_Status', hue='Gender', data=df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %% [markdown]
# # City_Category column

# %%
sb.countplot(x='City_Category', data=df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %% [markdown]
# ### Age group belonging to what all city's

# %%
sb.countplot(x='City_Category', hue='Age', data=df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %% [markdown]
# ### Marital status based on city's

# %%
sb.countplot(x='Marital_Status', hue='City_Category', data=df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %% [markdown]
# ### Pie-chart : City_Category distribution

# %%
df.groupby('City_Category').size().plot(kind='pie', autopct='%.1f', figsize=(4,4))
# Out:
# <Axes: >

# %% [markdown]
# ### Count of Gender's in each city

# %%
sb.countplot(x = 'City_Category', hue = 'Gender', data = df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %% [markdown]
# ## Amount spent in city

# %%
df.groupby('City_Category').size()
# Out:
# City_Category
# A    144638
# B    226493
# C    166446
# dtype: int64

# %%
df.groupby('City_Category').sum()['Purchase'].plot(kind='pie', autopct='%.1f')
# Out:
# <Axes: ylabel='Purchase'>

# %% [markdown]
# ## Avg spending by cutomers in each city

# %%
#df.groupby('City_Category').mean()['Purchase'].plot(kind='pie', autopct='%.1f')

# %%
df.head(10)
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000001  P00069042      F   0-17          10             A
# 1  1000001  P00248942      F   0-17          10             A
# 2  1000001  P00087842      F   0-17          10             A
# 3  1000001  P00085442      F   0-17          10             A
# 4  1000002  P00285442      M    55+          16             C
# 5  1000003  P00193542      M  26-35          15             A
# 6  1000004  P00184942      M  46-50           7             B
# 7  1000004  P00346142      M  46-50           7             B
# 8  1000004   P0097242      M  46-50           7             B
# 9  1000005  P00274942      M  26-35          20             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# ...

# %% [markdown]
# # Stay_In_Current_City_Years Coulmn

# %%
sb.set(rc={'figure.figsize':(4,4)})
sb.countplot(x='Stay_In_Current_City_Years', data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
df.groupby('Stay_In_Current_City_Years').size().plot(kind='pie', autopct="%.1f",)
# Out:
# <Axes: >

# %% [markdown]
# ### How many Years are Male and female staying in city

# %%
sb.countplot(x='Stay_In_Current_City_Years', hue='Gender', data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %% [markdown]
# ##### Males are staying more than females for 1 year

# %% [markdown]
# ### How many of them are married or bachelor

# %%
sb.countplot(x='Stay_In_Current_City_Years', hue='Marital_Status', data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %% [markdown]
# #### MOst of the men who are staying for 1 year are bachelor's-->target audience

# %% [markdown]
# ### In which city , Men are staying for 1 year

# %%
sb.countplot(x='Stay_In_Current_City_Years', hue='City_Category', data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %% [markdown]
# #### In City B , most of our target audience lies

# %% [markdown]
# ### In this , What is the age grp spending most

# %%
sb.countplot(x='Stay_In_Current_City_Years', hue='Age', data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %% [markdown]
# ## Conclusion :
#
# #### Target audience : staying-1yr,men,bachelor,city B, 26-35yrs old

# %% [markdown]
# ## Occupation Column

# %% [markdown]
# ### Total spending 's

# %%
df.groupby('Stay_In_Current_City_Years').size()
# Out:
# Stay_In_Current_City_Years
# 0      72725
# 1     189192
# 2      99459
# 3      93312
# 4+     82889
# dtype: int64

# %%
df.groupby('Stay_In_Current_City_Years').sum()['Purchase'].plot(kind='bar')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
## MEAN()

# %% [markdown]
# # Occupation Column

# %%
sb.countplot(x=df['Occupation'])
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby('Occupation').size().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %% [markdown]
# #### occupation 4 spends more

# %%
df.groupby('Occupation').sum()['Purchase'].sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %% [markdown]
# ## Marital status of occupation

# %%
sb.countplot(x='Occupation', hue='Marital_Status', data=df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %% [markdown]
# #### More bachelor's in all occupations

# %% [markdown]
# ### Gender's divison in Occupation

# %%
sb.countplot(x='Occupation', hue='Gender', data=df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %% [markdown]
# #### more dominance of men in all occupation except in 9

# %% [markdown]
# ## Different productsID in all occupations

# %%
df.groupby('Occupation').nunique()['Product_ID'].plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %% [markdown]
# ### sorting

# %%
df.groupby('Occupation').nunique()['Product_ID'].sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %% [markdown]
# #### 0 productID is having highest quantity being sold
# use mean() to find which productID is expensive and which is cheap

# %% [markdown]
# # Product_Category_1 Column

# %%
df.groupby('Product_Category_1').size().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %% [markdown]
# #### sorting:

# %%
df.groupby('Product_Category_1').size().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %% [markdown]
# #### Prodct 5 having largest stocks being sold

# %% [markdown]
# ### Amount generation from each element of product_category_1

# %%
df.groupby('Product_Category_1').sum()['Purchase'].sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %% [markdown]
# #### product 1 generating the highest revenue

# %% [markdown]
# ### Top 10 largest amount generating products , whose individual cost is high

# %%
df.groupby('Product_ID').sum()['Purchase'].nlargest(10).sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %% [markdown]
# ## Product selling the most but individual cost - cheap

# %%
df.groupby('Product_ID').size().nlargest(10).sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %%
## Gender ratio in Product_categroy_1

# %%
sb.countplot(x = 'Product_Category_1', hue = 'Gender', data = df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %% [markdown]
# #### most of men in product_Cat_1

# %%
sb.countplot(x = 'Product_Category_1', hue = 'Marital_Status', data = df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %% [markdown]
# #### most of the unmaaried/bachelor are buying pr_cat_1

# %% [markdown]
# # Combining Gender & Marital_Status

# %%
lst=[]
for i in range(len(df)):
    lst.append(df['Gender'][i]+'_'+str(df['Marital_Status'][i]))
    
df['MaritalGender']=lst

# %%
df.head(5)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase  \
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969
#
#   MaritalGender
# 0           F_0
# 1           F_0
# 2           F_0
# 3           F_0
# 4           M_0

# %%
sb.countplot(x=df['MaritalGender'])
# Out:
# <Axes: xlabel='MaritalGender', ylabel='count'>

# %% [markdown]
# ## On Age parameter, MaritalGender is

# %%
sb.countplot(x='Age', hue='MaritalGender', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %% [markdown]
# #### Most of men(unmarried) within the age:26-35 are the buying in sale

# %% [markdown]
# ### On Product_Category_1 , the MaritalGender is

# %%
sb.countplot(x='Product_Category_1', hue='MaritalGender', data=df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
# Staying in city on MaritalGender

# %% [markdown]
# #### Prodict 1,5,8,11 are being most by men(unmarried)

# %%
sb.countplot(x = df['Stay_In_Current_City_Years'], hue = df['MaritalGender'])
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %% [markdown]
# Staying in cuurent city years in highest ascending order are :<br><br>
# 1>Men(unmarried)<br>
# 2>Men(married)<br>
# 3>Female(Unmarried)<br>
# 4>Femel(married)

# %% [markdown]
# ### City category vs Marital gender

# %%
sb.countplot(x='City_Category', hue='MaritalGender', data=df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %% [markdown]
# #### City B with men(unmarried)
